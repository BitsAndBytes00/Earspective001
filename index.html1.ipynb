# %%
<!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN" "http://www.w3.org/TR/html4/strict.dtd">
<html>
<head>
  <meta content="text/html; charset=ISO-8859-1"
 http-equiv="content-type">
  <title>index.html</title>
</head>
<body>
<div style="text-align: center;">By proceeding,you agree
to the <br>
terms of our<a target="_blank"
 href="tems%20and%20condition.html.html"> <span
 style="text-decoration: underline; font-weight: bold; font-style: italic;">Privacy
Statement</span></a></div>
</body>
</html>
<!DOCTYPE html PUBLIC "-//W3C//DTD HTML 4.01//EN" "http://www.w3.org/TR/html4/strict.dtd">
<html>
<head>
  <meta content="text/html; charset=ISO-8859-1"
 http-equiv="content-type">
  <title>tems and condition.html</title>
</head>
<body>
<div style="text-align: left;"><big><span
 style="font-weight: bold;">Applicability of privacy statement</span><br>
<br>
This Privacy statement relates to"<span style="font-weight: bold;">personal
information</span>", meaning information about an identifiable
individual. Whether a person is "<span style="font-weight: bold;">identifiable</span>"
means that they can be identified by the information itself or by that
information combined with other information reasonably available.<br>
This
Privacy Statement applies to Personal Information processed by
EARSPECTIVE through use of the EARSPECTIVE Solutions. This Privacy
Statement also<br>
applies to information that is collected via our
websites. In this Privacy Statement, we may also refer to our Customer,
which is the organization that is primarily responsible for the
collection, use, and disclosure of Participant information, as the "<span
 style="font-weight: bold;">Custodian</span>" or "<span
 style="font-weight: bold;">Data Controller</span>".<br>
<br>
<span style="font-weight: bold;">Participant Personal
Information</span><br style="font-weight: bold;">
<br>
The term "<span style="font-weight: bold;">Participant</span>"
refers to those individuals whose hearing screening results and/or
other information are collected and processed using the&nbsp;</big><big>EARSPECTIVE</big><big>
Solutions.<br>
<br>
We are managers of Participant Personal Information as service
providers to our "<span style="font-weight: bold;">Customers</span>",
which are the organizations and individuals that license access to, and
use of, the&nbsp;</big><big>EARSPECTIVE</big><big>
Solutions from us. The collection, use, and disclosure of Participant
Personal Information will also be subjectto the privacy practices of
the relevant Customers, so Participants should refer to them for
additional information.<br>
<br>
Participants should also be aware that Customers are able to export
data from the</big><big> EARSPECTIVE</big><big>Solutions.
Customers are solely responsible for the use of such data and for
safeguarding it. Participants should therefore be aware that their
Personal Information may also be directly held by the relevant Customer.<br>
<br>
EARSPECTIVE
Online may include links to third-party websites, plug-ins and
applications, for example, to book an appointment to meet with a
hearing care provider. Clicking on those links or enabling those
connections may allow third parties, including our Customer, to collect
or share data about you. We do not control these third-party websites
and are not responsible for their privacy statements. When you
leave&nbsp;</big><big>EARSPECTIVE</big><big>
Online, we encourage you to read the privacy statements of those
websites.<br>
<br>
<span style="font-weight: bold;">What information we
collect</span><br>
<br>
The use of </big><big>EARSPECTIVE </big><big>Online
may involve the collection and processing of the following Participant
Personal Information on behalf of Customers:<br>
</big><big>•</big><big>First name<br>
</big><big>•</big><big>Last name<br>
</big><big>•</big><big>Email address<br>
</big><big>•</big><big>Phone number</big><big><br>
• Age range<br>
• Gender<br>
</big><big>•</big><big>Hearing screening results<br>
<br>
Participants should be aware that our Customers collect Participant
Personal Information using a questionnaire within&nbsp;</big><big>EARSPECTIVE</big><big>
Online. The questionnaire is always mandatory and some Customers may
make name, email address, physical address and phone number mandatory
as well. Providing any other information for </big><big>EARSPECTIVE
</big><big>Online is optional.<br>
<br>
<span style="font-weight: bold;">Purposes for collection</span><br>
<br>
</big><big>EARSPECTIVE</big><big>&nbsp;does
not use any identifiable Participant Personal Information for its own
purposes. Participant Personal Information is only processed by </big><big>EARSPECTIVE</big><big>
on behalf of our Customers to provide them with the </big><big>EARSPECTIVE
</big><big>Solutions.
Participants should refer to the Customer's privacy policy for an
understanding of how Participant Personal Information is collected,
used, disclosed, and otherwise processed by the Customer through its
use of the </big><big>EARSPECTIVE </big><big>Solutions
before submitting any Personal Information to the </big><big>EARSPECTIVE</big><big>
Solutions. Further, if you have any questions or concerns about the
processing of your Personal Information, you should consult the
Custodian.<br>
<br>
<span style="font-weight: bold;">Disclosure of Personal
Information</span><br>
<br>
</big><big>EARSPECTIVE</big><big>&nbsp;may
share Personal Information with people within the company who have a
"need to know" the information for business or legal reasons.<br>
<br>
•
Government and regulatory authorities. For example, to respond to a
legal request or comply with a legal obligation, in which case we will
make reasonable efforts to give the relevant individual notice of the
disclosure, provided we are able to identify the individual and are
lawfully able to do so;<br>
<br>
• For the purposes of seeking legal or other professional advice;<br>
<br>
</big><big><br>
<span style="font-weight: bold;">Right of Access</span><br>
<br>
Pursuant
to applicable law, you may have certain rights in relation to your
Personal Information, including a right of access. Participants should
contact the relevant Custodian directly and the Custodian can
facilitate this access directly by use of the</big><big>EARSPECTIVE
</big><big>Solutions.
If we are required to assist the Custodian, we may require additional
information to confirm a Participant's identity, which will only be
used for that purpose.<br>
<br>
<span style="font-weight: bold;">Safeguarding Personal
Information</span><br style="font-weight: bold;">
<br>
We
are required by law to safeguard the Personal Information in our
custody or control. We use industry standard measures to protect
Personal Information against loss or theft, as well as unauthorized
access, disclosure, copying, use, or modification. We protect Personal
Information regardless of the format in which it is held. We recognize
that Participant Personal Information may contain sensitive health
information and we protect it accordingly.<br>
<br>
<span style="font-weight: bold;">Anonymous information</span><br>
<br>
</big><big>EARSPECTIVE</big><big>&nbsp;collects,
compiles and analyzes anonymous, aggregate and/or de-identified data
derived from Customers' and Participants' access to and use of the </big><big>EARSPECTIVE
</big><big>Solutions, including Personal Information
("Compiled Data").&nbsp;</big><big>EARSPECTIVE</big><big>
employs an automated system to securely de-identify the data used to
create the Compiled Data and then&nbsp;analyse on the Compiled Data.<br>
<br>
</big>
<div style="text-align: center;">
<div style="text-align: center;"><button
 name=" I ,AGREE TO THE TERMS AND CONDITION">&nbsp;<span
 style="font-weight: bold;">I ,AGREE TO THE TERMS AND
CONDITION</span><br style="font-weight: bold;">
<br style="font-weight: bold;">
<span style="font-style: italic; font-weight: bold;"></span></button><br>
</div>
<big><br>
</big></div>
<big><br>
<br>
<span style="font-weight: bold;"></span><br>
<br>
<br>
<br>
<br>
<br>
</big></div>
</body>
</html>
